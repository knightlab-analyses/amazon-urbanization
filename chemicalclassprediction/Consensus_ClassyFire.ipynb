# %% [markdown]
# ## Retrieve ClassyFire consensus chemical classes per mass spectral molecular family

# %% [markdown]
# **Author**: Madeleine Ernst (mernst@ucsd.edu)

# %% [markdown]
# load libraries

# %%
import pandas as pd  
import csv  
from classyfire import * # retrieved from https://github.com/DorresteinLaboratory/NAP_ProteoSAFe/tree/master/formatdb
from classyfire_consensus import * 
import os

# %% [markdown]
# load results from <i>in silico</i> predicted structres trhough Network Annotation Propagation (NAP) downloaded from https://proteomics2.ucsd.edu/ProteoSAFe/status.jsp?task=af425ada55d54adca9c7b28a823af54c (Download Summary Report, unzip folder, load file within folder named 'final_out')

# %%
nap1 = pd.read_csv("node_attributes_table.tsv", sep='\t')

# %%
nap1.head()
# Out:
#    cluster.index  parent.mass  number.of.spectra     RTMean  \
# 0              1       81.520                 54  599.74356
# 1              4       81.520                  8  599.32475
# 2              5       81.520                  9  599.43322
# 3              7       87.967                247  600.07314
# 4              8       88.018                 23  599.94643
#
#    sum.precursor.intensity. LibraryID SpectrumID Smiles INCHI  \
# 0                   1316240       NaN        NaN    NaN   NaN
# 1                    165116       NaN        NaN    NaN   NaN
# 2                    221988       NaN        NaN    NaN   NaN
# 3                   5365030       NaN        NaN    NaN   NaN
# 4                    562220       NaN        NaN    NaN   NaN
#
#                                ProteoSAFeClusterLink MetFragScore  \
# 0  http://gnps.ucsd.edu//ProteoSAFe/result.jsp?ta...          NaN
# 1  http://gnps.ucsd.edu//ProteoSAFe/result.jsp?ta...          NaN
# 2  http://gnps.ucsd.edu//ProteoSAFe/result.jsp?ta...          NaN
# 3  http://gnps.ucsd.edu//ProteoSAFe/result.jsp?ta...          NaN
# 4  http://gnps.ucsd.edu//ProteoSAFe/result.jsp?ta...          NaN
#
#   MetFragSMILES MetFragID FusionScore FusionSMILES FusionID ConsensusScore  \
# 0           NaN       NaN         NaN          NaN      NaN            NaN
# 1           NaN       NaN         NaN          NaN      NaN            NaN
# 2           NaN       NaN         NaN          NaN      NaN            NaN
# 3           NaN       NaN         NaN          NaN      NaN            NaN
# 4           NaN       NaN         NaN          NaN      NaN            NaN
#
#   ConsensusSMILES ConsensusID
# 0             NaN         NaN
# 1             NaN         NaN
# 2             NaN         NaN
# 3             NaN         NaN
# 4             NaN         NaN

# %% [markdown]
# ### Convert all unique SMILES to InChIKeys

# %% [markdown]
# retrieve all unique SMILES structures

# %%
matches = [nap1]

# %%
out = unique_smiles(matches)
df = out['df']

# %% [markdown]
# write unique SMILES structures to file and convert to InChIKeys using MolConverter <br> https://chemaxon.com/marvin-archive/3.3.3/marvin/doc/user/molconvert.html

# %%
df.to_csv("SMILES_Amazon.csv", quoting=csv.QUOTE_NONE, escapechar='&')

# %%
os.system('/Applications/MarvinSuite/bin/molconvert inchikey:SAbs /Users/madeleineernst/Documents/AmazonProject/SMILES_Amazon.csv{csv:strucSMILES} -o /Users/madeleineernst/Documents/AmazonProject/InchiKeys_Amazon.txt')
# Out:
# 0

# %% [markdown]
# ### Submit unique InChIKeys to ClassyFire

# %%
df = pd.read_csv("SMILES_Amazon.csv",  sep=',', index_col = 0)

# %%
ikeys = pd.read_csv("InchiKeys_Amazon.txt",  sep='\t',header = None)
ikeys = [j for i in ikeys.values.tolist() for j in i]
ikeys = [w.replace('InChIKey=', '') for w in ikeys]

# %%
df.head()
# Out:
#                                               SMILES
# 0  CCCCC[C@@H]1Cc2cc(c(cc2c2c1c1c(cc2OC)O[C@H]([C...
# 1  C[C@@H]1CN([C@@H](C)CO)C(=O)c2ccccc2c2ccccc2CO...
# 2  C[C@@]12CC[C@@H]3[C@]([C@H]1CC[C@H]([C@H]2CC(=...
# 3  c1cn([C@H]2C[C@@H]([C@@H](CO)O2)OP(=O)(O)OC[C@...
# 4  [H][C@@](COC(=O)CCCCCCC\C=C/CCCCCCCC)(COP(O)(O...

# %%
df["inchikey"] = ikeys

# %%
df.head()
# Out:
#                                               SMILES  \
# 0  CCCCC[C@@H]1Cc2cc(c(cc2c2c1c1c(cc2OC)O[C@H]([C...
# 1  C[C@@H]1CN([C@@H](C)CO)C(=O)c2ccccc2c2ccccc2CO...
# 2  C[C@@]12CC[C@@H]3[C@]([C@H]1CC[C@H]([C@H]2CC(=...
# 3  c1cn([C@H]2C[C@@H]([C@@H](CO)O2)OP(=O)(O)OC[C@...
# 4  [H][C@@](COC(=O)CCCCCCC\C=C/CCCCCCCC)(COP(O)(O...
#
#                       inchikey
# 0  UMMCDLJLAGZVAD-QBHLMYNQSA-N
# 1  QXIWLMKZHSHPSY-WENCSYSZSA-N
# 2  CKEZEKFAEZIJLA-UQMLBVKCSA-N
# 3  OBCJQWSXSLYWHI-WKSZEZMPSA-N
# 4  PFNZHCWBORLUPP-RDHALYEDSA-N

# %% [markdown]
# submit all unique InChIKeys to ClassyFire

# %%
classy = query_inchikey(list(set(ikeys)))

# %%
classy.head()
# Out:
#                               class  \
# 0  Steroids and steroid derivatives
# 1                     Prenol lipids
# 2                     Prenol lipids
# 3                     Prenol lipids
# 4  Carboxylic acids and derivatives
#
#                                        direct_parent  \
# 0                       Stigmastanes and derivatives
# 1                            Aromatic monoterpenoids
# 2  Eudesmanolides, secoeudesmanolides, and deriva...
# 3                            Aromatic monoterpenoids
# 4               Hexacarboxylic acids and derivatives
#
#                       inchikey            kingdom  \
# 0  KOMFLQBTVSCQMC-DEDJOHNFSA-N  Organic compounds
# 1  ZNBRGKRSUQTAJM-LSQMVHIFSA-O  Organic compounds
# 2  AYWGUJVWIMXXNN-AVCOQLNBSA-O  Organic compounds
# 3  DULRAFVTZYWWOW-JXGGLGGMSA-O  Organic compounds
# 4  KVNXXXFZZIWSSE-VRVGQERDSA-N  Organic compounds
#
#                    molecular_framework                              subclass  \
# 0   Aliphatic homopolycyclic compounds          Stigmastanes and derivatives
# 1  Aromatic heteromonocyclic compounds                        Monoterpenoids
# 2  Aromatic heteropolycyclic compounds                      Terpene lactones
# 3  Aromatic heteropolycyclic compounds                        Monoterpenoids
# 4          Aliphatic acyclic compounds  Hexacarboxylic acids and derivatives
#
#                         superclass
# 0  Lipids and lipid-like molecules
# 1  Lipids and lipid-like molecules
# 2  Lipids and lipid-like molecules
# 3  Lipids and lipid-like molecules
# 4    Organic acids and derivatives

# %%
classy.to_csv("Classy_Amazon.csv", sep = '\t')

# %% [markdown]
# ### Retrieve most abundant chemical classes per mass spectral molecular family

# %%
classy = pd.read_csv("Classy_Amazon.csv", sep='\t',index_col =0)

# %%
classy.head()
# Out:
#                               class  \
# 0  Steroids and steroid derivatives
# 1                     Prenol lipids
# 2                     Prenol lipids
# 3                     Prenol lipids
# 4  Carboxylic acids and derivatives
#
#                                        direct_parent  \
# 0                       Stigmastanes and derivatives
# 1                            Aromatic monoterpenoids
# 2  Eudesmanolides, secoeudesmanolides, and deriva...
# 3                            Aromatic monoterpenoids
# 4               Hexacarboxylic acids and derivatives
#
#                       inchikey            kingdom  \
# 0  KOMFLQBTVSCQMC-DEDJOHNFSA-N  Organic compounds
# 1  ZNBRGKRSUQTAJM-LSQMVHIFSA-O  Organic compounds
# 2  AYWGUJVWIMXXNN-AVCOQLNBSA-O  Organic compounds
# 3  DULRAFVTZYWWOW-JXGGLGGMSA-O  Organic compounds
# 4  KVNXXXFZZIWSSE-VRVGQERDSA-N  Organic compounds
#
#                    molecular_framework                              subclass  \
# 0   Aliphatic homopolycyclic compounds          Stigmastanes and derivatives
# 1  Aromatic heteromonocyclic compounds                        Monoterpenoids
# 2  Aromatic heteropolycyclic compounds                      Terpene lactones
# 3  Aromatic heteropolycyclic compounds                        Monoterpenoids
# 4          Aliphatic acyclic compounds  Hexacarboxylic acids and derivatives
#
#                         superclass
# 0  Lipids and lipid-like molecules
# 1  Lipids and lipid-like molecules
# 2  Lipids and lipid-like molecules
# 3  Lipids and lipid-like molecules
# 4    Organic acids and derivatives

# %%
df = pd.merge(df, classy, on="inchikey", how = 'left')

# %%
df.head()
# Out:
#                                               SMILES  \
# 0  CCCCC[C@@H]1Cc2cc(c(cc2c2c1c1c(cc2OC)O[C@H]([C...
# 1  C[C@@H]1CN([C@@H](C)CO)C(=O)c2ccccc2c2ccccc2CO...
# 2  C[C@@]12CC[C@@H]3[C@]([C@H]1CC[C@H]([C@H]2CC(=...
# 3  c1cn([C@H]2C[C@@H]([C@@H](CO)O2)OP(=O)(O)OC[C@...
# 4  [H][C@@](COC(=O)CCCCCCC\C=C/CCCCCCCC)(COP(O)(O...
#
#                       inchikey                                 class  \
# 0  UMMCDLJLAGZVAD-QBHLMYNQSA-N                            Flavonoids
# 1  QXIWLMKZHSHPSY-WENCSYSZSA-N   Benzene and substituted derivatives
# 2  CKEZEKFAEZIJLA-UQMLBVKCSA-N      Steroids and steroid derivatives
# 3  OBCJQWSXSLYWHI-WKSZEZMPSA-N  (3'->5')-dinucleotides and analogues
# 4  PFNZHCWBORLUPP-RDHALYEDSA-N                  Glycerophospholipids
#
#                      direct_parent            kingdom  \
# 0        7-O-methylated flavonoids  Organic compounds
# 1                       Benzamides  Organic compounds
# 2                   16-oxosteroids  Organic compounds
# 3           (3'->5')-dinucleotides  Organic compounds
# 4  1,2-diacylglycerol-3-phosphates  Organic compounds
#
#                     molecular_framework                       subclass  \
# 0   Aromatic heteropolycyclic compounds        O-methylated flavonoids
# 1   Aromatic heteropolycyclic compounds  Benzoic acids and derivatives
# 2  Aliphatic heteropolycyclic compounds                    Oxosteroids
# 3   Aromatic heteropolycyclic compounds         (3'->5')-dinucleotides
# 4           Aliphatic acyclic compounds              Glycerophosphates
#
#                                 superclass
# 0         Phenylpropanoids and polyketides
# 1                               Benzenoids
# 2          Lipids and lipid-like molecules
# 3  Nucleosides, nucleotides, and analogues
# 4          Lipids and lipid-like molecules

# %%
df = df.rename(columns = {'class':'CF_class'})

# %% [markdown]
# load mass spectral molecular network data downloaded from https://gnps.ucsd.edu/ProteoSAFe/status.jsp?task=549cfafcdaef4a7496768f45bb90771c (Download Cytoscape Data, unzip folder, load file within folder named 'clusterinfosummarygroup_attributes_withIDs_withcomponentID')

# %%
net = pd.read_csv("83507be33e0d4aa984b7d43b0a1d127b.tsv",  sep='\t')

# %%
net.head()
# Out:
#    cluster index  number of spectra  parent mass  precursor charge  \
# 0         684980                  4      867.600                 0
# 1         524499                 64      437.344                 0
# 2         681603                  6      837.589                 0
# 3         393578                  3      330.265                 0
# 4         684238                  3      865.621                 0
#
#    precursor mass  sum(precursor intensity)  2012  2013  Checherta  Iquitos  \
# 0         867.600                  199760.0     0     4          0        0
# 1         437.344                 2105100.0    64     0         30        7
# 2         837.589                  271948.0     0     6          0        0
# 3         330.265                   79260.0     3     0          3        0
# 4         865.621                  178028.0     0     3          0        0
#
#         ...        DefaultGroups      RTMean  RTStdErr  \
# 0       ...                  G1,  452.586250  1.862014
# 1       ...                  G1,  483.722594  1.254104
# 2       ...                  G1,  467.492500  1.127573
# 3       ...                  G1,  241.924000  0.982704
# 4       ...                  G1,  526.001667  1.147844
#
#                                ProteoSAFeClusterLink  UniqueFileSourcesCount  \
# 0  http://gnps.ucsd.edu//ProteoSAFe/result.jsp?ta...                       4
# 1  http://gnps.ucsd.edu//ProteoSAFe/result.jsp?ta...                      52
# 2  http://gnps.ucsd.edu//ProteoSAFe/result.jsp?ta...                       6
# 3  http://gnps.ucsd.edu//ProteoSAFe/result.jsp?ta...                       2
# 4  http://gnps.ucsd.edu//ProteoSAFe/result.jsp?ta...                       3
#
#    EvenOdd  LibraryID  NumberOrganismIDs  AllOrganisms  componentindex
# 0        0        NaN                  0           NaN              -1
# 1        0        NaN                  0           NaN               1
# 2        0        NaN                  0           NaN              -1
# 3        1        NaN                  0           NaN              -1
# 4        0        NaN                  0           NaN              -1
#
# [5 rows x 47 columns]

# %%
final = molfam_classes(net,df,out['dic'])

# %%
final.head()
# Out:
#    cluster index  componentindex  CF_NrNodes         CF_kingdom  \
# 0         524499               1           6  Organic compounds
# 1         524547               1           6  Organic compounds
# 2         524551               1           6  Organic compounds
# 3         524511               1           6  Organic compounds
# 4         524516               1           6  Organic compounds
#
#   CF_kingdom_score                    CF_superclass CF_superclass_score  \
# 0                1  Lipids and lipid-like molecules            0.916667
# 1                1  Lipids and lipid-like molecules            0.916667
# 2                1  Lipids and lipid-like molecules            0.916667
# 3                1  Lipids and lipid-like molecules            0.916667
# 4                1  Lipids and lipid-like molecules            0.916667
#
#         CF_class CF_class_score    CF_subclass CF_subclass_score  \
# 0  Prenol lipids       0.494444  Triterpenoids          0.272222
# 1  Prenol lipids       0.494444  Triterpenoids          0.272222
# 2  Prenol lipids       0.494444  Triterpenoids          0.272222
# 3  Prenol lipids       0.494444  Triterpenoids          0.272222
# 4  Prenol lipids       0.494444  Triterpenoids          0.272222
#
#       CF_Dparent CF_Dparent_score                       CF_MFramework  \
# 0  Triterpenoids         0.272222  Aliphatic homopolycyclic compounds
# 1  Triterpenoids         0.272222  Aliphatic homopolycyclic compounds
# 2  Triterpenoids         0.272222  Aliphatic homopolycyclic compounds
# 3  Triterpenoids         0.272222  Aliphatic homopolycyclic compounds
# 4  Triterpenoids         0.272222  Aliphatic homopolycyclic compounds
#
#   CF_MFramework_score
# 0            0.672222
# 1            0.672222
# 2            0.672222
# 3            0.672222
# 4            0.672222

# %% [markdown]
# write per node chemical class output table

# %%
final.to_csv("ClassyFire_InputforCytoscape_Amazon.csv", sep = '\t', index = False)

# %% [markdown]
# ### Create chemical class feature table

# %% [markdown]
# load per node chemical class output table

# %%
cf = pd.read_csv('ClassyFire_InputforCytoscape_Amazon_New.csv',sep='\t')

# %% [markdown]
# load mass spectral molecular bucket table, downloaded from https://gnps.ucsd.edu/ProteoSAFe/status.jsp?task=549cfafcdaef4a7496768f45bb90771c

# %%
ft = pd.read_csv('METABOLOMICS-SNETS-549cfafc-download_cluster_buckettable-main.tsv',sep='\t')

# %% [markdown]
# calculate number of nodes per chemical superclass

# %%
cf = cf.rename(columns = {'cluster index':'cluster.index'})
ft = ft.rename(columns = {'#OTU ID':'cluster.index'})

comb = pd.merge(cf, ft, on="cluster.index")
rem = ['componentindex']

comb = comb.drop(rem, 1)

subcl = comb.CF_superclass.unique()

subcl_df = []
for i in range(len(subcl)):
    sel = comb.loc[comb['CF_superclass'] == subcl[i]] 
    out = sel.astype(bool).sum(axis=0)
    out = out.to_dict()
    subcl_df.append(out)

df = pd.DataFrame(subcl_df)
df.insert(loc=0, column='id', value= list(subcl))
df = df.drop('cluster.index', 1)
df = df[df.columns.drop(list(df.filter(regex='CF')))] 
df = df[df.id != 'no matches']
df = df[-df['id'].isnull()]

# %%
df.to_csv("featuretable_superclass.tsv",sep='\t',index=False)
